# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Used Car Dataset.csv')

# %%
data.head()
# Out:
#                                             car_name registration_year  \
# 0                    2017 Mercedes-Benz S-Class S400            Jul-17
# 1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI            Jan-21
# 2                       2018 BMW X1 sDrive 20d xLine            Sep-18
# 3                           2019 Kia Seltos GTX Plus            Dec-19
# 4                    2019 Skoda Superb LK 1.8 TSI AT            Aug-19
#
#   insurance_validity fuel_type  seats  kms_driven   ownsership transmission  \
# 0      Comprehensive    Petrol    5.0       56000  First Owner    Automatic
# 1      Comprehensive    Petrol    5.0       30615  First Owner    Automatic
# 2      Comprehensive    Diesel    5.0       24000  First Owner    Automatic
# 3      Comprehensive    Petrol    5.0       18378  First Owner       Manual
# 4      Comprehensive    Petrol    5.0       44900  First Owner    Automatic
#
#    manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# ...

# %%
data.shape
# Out:
# (1553, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1553 non-null   object
#  1   registration_year   1553 non-null   object
#  2   insurance_validity  1553 non-null   object
#  3   fuel_type           1551 non-null   object
#  4   seats               1551 non-null   float64
#  5   kms_driven          1553 non-null   int64
#  6   ownsership          1503 non-null   object
#  7   transmission        1503 non-null   object
#  8   manufacturing_year  1503 non-null   float64
#  9   mileage(kmpl)       1550 non-null   float64
#  10  engine(cc)          1550 non-null   float64
#  11  max_power(bhp)      1550 non-null   float64
#  12  torque(Nm)          1549 non-null   float64
#  13  price(in lakhs)     1553 non-null   float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 170.0+ KB

# %%
data.describe()
# Out:
#              seats     kms_driven  manufacturing_year  mileage(kmpl)  \
# count  1551.000000    1553.000000         1503.000000    1550.000000
# mean      5.202450   52841.931101         2017.371257     236.927277
# std       0.631655   40067.800347            3.008293     585.964295
# min       4.000000     620.000000         2007.000000       7.810000
# 25%       5.000000   30000.000000         2015.000000      16.342500
# 50%       5.000000   49134.000000         2018.000000      18.900000
# 75%       5.000000   70000.000000         2019.000000      22.000000
# max       8.000000  810000.000000         2023.000000    3996.000000
#
#          engine(cc)  max_power(bhp)    torque(Nm)  price(in lakhs)
# count  1.550000e+03    1.550000e+03  1.549000e+03      1553.000000
# mean   1.471857e+10    1.471857e+10  1.423989e+04       166.141494
# std    2.185629e+11    2.185629e+11  9.666241e+04      3478.855090
# min    5.000000e+00    5.000000e+00  5.000000e+00         1.000000
# ...

# %%
data.isnull().sum()
# Out:
# car_name               0
# registration_year      0
# insurance_validity     0
# fuel_type              2
# seats                  2
# kms_driven             0
# ownsership            50
# transmission          50
# manufacturing_year    50
# mileage(kmpl)          3
# engine(cc)             3
# max_power(bhp)         3
# torque(Nm)             4
# price(in lakhs)        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            0
# max_power(bhp)        0
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64

# %%
data.shape
# Out:
# (1499, 14)

# %%
data.columns
# Out:
# Index(['car_name', 'registration_year', 'insurance_validity', 'fuel_type',
#        'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %%
data.drop('car_name', axis=1, inplace=True)

# %%
data.shape
# Out:
# (1499, 13)

# %%
data.head()
# Out:
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol    5.0       56000
# 1            Jan-21      Comprehensive    Petrol    5.0       30615
# 2            Sep-18      Comprehensive    Diesel    5.0       24000
# 3            Dec-19      Comprehensive    Petrol    5.0       18378
# 4            Aug-19      Comprehensive    Petrol    5.0       44900
#
#     ownsership transmission  manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic              2017.0           7.81      2996.0
# 1  First Owner    Automatic              2020.0          17.40       999.0
# 2  First Owner    Automatic              2018.0          20.68      1995.0
# 3  First Owner       Manual              2019.0          16.50      1353.0
# 4  First Owner    Automatic              2019.0          14.67      1798.0
#
#    max_power(bhp)  torque(Nm)  price(in lakhs)
# 0          2996.0       333.0            63.75
# ...

# %%
data.drop('registration_year', axis=1, inplace=True)

# %%
data.head()
# Out:
#   insurance_validity fuel_type  seats  kms_driven   ownsership transmission  \
# 0      Comprehensive    Petrol    5.0       56000  First Owner    Automatic
# 1      Comprehensive    Petrol    5.0       30615  First Owner    Automatic
# 2      Comprehensive    Diesel    5.0       24000  First Owner    Automatic
# 3      Comprehensive    Petrol    5.0       18378  First Owner       Manual
# 4      Comprehensive    Petrol    5.0       44900  First Owner    Automatic
#
#    manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  \
# 0              2017.0           7.81      2996.0          2996.0       333.0
# 1              2020.0          17.40       999.0           999.0      9863.0
# 2              2018.0          20.68      1995.0          1995.0       188.0
# 3              2019.0          16.50      1353.0          1353.0     13808.0
# 4              2019.0          14.67      1798.0          1798.0     17746.0
#
#    price(in lakhs)
# 0            63.75
# ...

# %%
data.nunique()
# Out:
# insurance_validity      5
# fuel_type               3
# seats                   5
# kms_driven            704
# ownsership              4
# transmission            2
# manufacturing_year     16
# mileage(kmpl)         323
# engine(cc)            130
# max_power(bhp)        130
# torque(Nm)            272
# price(in lakhs)       622
# dtype: int64

# %%
data['insurance_validity'].value_counts()
# Out:
# insurance_validity
# Comprehensive            1081
# Third Party insurance     289
# Zero Dep                   64
# Third Party                63
# Not Available               2
# Name: count, dtype: int64

# %%
data['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    997
# Diesel    480
# CNG        22
# Name: count, dtype: int64

# %%
data['ownsership'].value_counts()
# Out:
# ownsership
# First Owner     1236
# Second Owner     240
# Third Owner       21
# Fifth Owner        2
# Name: count, dtype: int64

# %%
data['transmission'].value_counts()
# Out:
# transmission
# Manual       832
# Automatic    667
# Name: count, dtype: int64

# %%
data['seats'].value_counts()
# Out:
# seats
# 5.0    1306
# 7.0     154
# 4.0      21
# 6.0      16
# 8.0       2
# Name: count, dtype: int64

# %%
def show_boxplot(data, column):
    data.boxplot(column=column)
    plt.title('Boxplot of ' + column)
    plt.ylabel(column)
    plt.show()

# %%
data.columns
# Out:
# Index(['insurance_validity', 'fuel_type', 'seats', 'kms_driven', 'ownsership',
#        'transmission', 'manufacturing_year', 'mileage(kmpl)', 'engine(cc)',
#        'max_power(bhp)', 'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1499 entries, 0 to 1552
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   insurance_validity  1499 non-null   object
#  1   fuel_type           1499 non-null   object
#  2   seats               1499 non-null   float64
#  3   kms_driven          1499 non-null   int64
#  4   ownsership          1499 non-null   object
#  5   transmission        1499 non-null   object
#  6   manufacturing_year  1499 non-null   float64
#  7   mileage(kmpl)       1499 non-null   float64
#  8   engine(cc)          1499 non-null   float64
#  9   max_power(bhp)      1499 non-null   float64
#  10  torque(Nm)          1499 non-null   float64
#  11  price(in lakhs)     1499 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 152.2+ KB

# %%
car_categorical_attributes = [
    "insurance_validity",
    "fuel_type",
    "ownsership",
    "transmission",
]

# %%
for column in car_categorical_attributes:
    print(data[column].value_counts())
    print('*' * 50)
# Out:
# insurance_validity
# Comprehensive            1081
# Third Party insurance     289
# Zero Dep                   64
# Third Party                63
# Not Available               2
# Name: count, dtype: int64
# **************************************************
# fuel_type
# Petrol    997
# Diesel    480
# CNG        22
# Name: count, dtype: int64
# **************************************************
# ownsership
# First Owner     1236
# Second Owner     240
# Third Owner       21
# Fifth Owner        2
# Name: count, dtype: int64
# **************************************************
# transmission
# Manual       832
# Automatic    667
# Name: count, dtype: int64
# **************************************************

# %%
data.shape
# Out:
# (1499, 12)

# %%
car_numerical_attributes = {
    "seats": "seats",
    "kms_driven": "kms_driven",
    "mileage": "mileage(kmpl)",
    "engine": "engine(cc)",
    "max_power": "max_power(bhp)",
    "manufacturing_year": "manufacturing_year",
    "torque": "torque(Nm)",
    "price": "price(in lakhs)"
}

# %%
data.describe()
# Out:
#              seats    kms_driven  manufacturing_year  mileage(kmpl)  \
# count  1499.000000    1499.00000         1499.000000    1499.000000
# mean      5.206137   53219.61441         2017.380921     187.284703
# std       0.636718   40404.02744            2.996381     516.597348
# min       4.000000     620.00000         2007.000000       7.810000
# 25%       5.000000   30000.00000         2015.000000      16.100000
# 50%       5.000000   49441.00000         2018.000000      18.760000
# 75%       5.000000   70000.00000         2019.000000      21.400000
# max       8.000000  810000.00000         2023.000000    3996.000000
#
#          engine(cc)  max_power(bhp)    torque(Nm)  price(in lakhs)
# count  1.499000e+03    1.499000e+03  1.499000e+03      1499.000000
# mean   1.521934e+10    1.521934e+10  1.274292e+04       171.506071
# std    2.222352e+11    2.222352e+11  8.269170e+04      3540.885094
# min    6.700000e+01    6.700000e+01  1.900000e+01         1.000000
# ...

# %%
show_boxplot(data, 'kms_driven')

# %%
data = data[data['kms_driven'] < 120000]

# %%
data.shape
# Out:
# (1455, 12)

# %%
show_boxplot(data, 'kms_driven')

# %%
data.describe()
# Out:
#              seats     kms_driven  manufacturing_year  mileage(kmpl)  \
# count  1455.000000    1455.000000         1455.000000    1455.000000
# mean      5.201375   49770.940206         2017.465292     192.420887
# std       0.631583   26141.988321            2.960770     523.496711
# min       4.000000     620.000000         2007.000000       7.810000
# 25%       5.000000   29923.000000         2016.000000      16.345000
# 50%       5.000000   49000.000000         2018.000000      18.800000
# 75%       5.000000   68948.500000         2019.000000      21.400000
# max       8.000000  118146.000000         2023.000000    3996.000000
#
#          engine(cc)  max_power(bhp)    torque(Nm)  price(in lakhs)
# count  1.455000e+03    1.455000e+03  1.455000e+03      1455.000000
# mean   1.567958e+10    1.567958e+10  1.303634e+04       176.447973
# std    2.255567e+11    2.255567e+11  8.391203e+04      3593.945785
# min    6.700000e+01    6.700000e+01  1.900000e+01         1.000000
# ...

# %%
show_boxplot(data, 'mileage(kmpl)')

# %%
q25 = data['mileage(kmpl)'].quantile(0.25)
q75 = data['mileage(kmpl)'].quantile(0.75)
iqr = q75 - q25
lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr
data = data[(data['mileage(kmpl)'] > lower_bound) & (data['mileage(kmpl)'] < upper_bound)]

# %%
data.shape
# Out:
# (1268, 12)

# %%
show_boxplot(data, 'mileage(kmpl)')

# %%
df = data.copy()

# %%
q25 = data['mileage(kmpl)'].quantile(0.25)
q75 = data['mileage(kmpl)'].quantile(0.75)
iqr = q75 - q25
lower_bound = q25 - 1.3 * iqr
upper_bound = q75 + 1.3 * iqr
df = df[(df['mileage(kmpl)'] > lower_bound) & (df['mileage(kmpl)'] < upper_bound)]

# %%
df.shape
# Out:
# (1232, 12)

# %%
show_boxplot(df, 'mileage(kmpl)')

# %%
df.describe()
# Out:
#              seats     kms_driven  manufacturing_year  mileage(kmpl)  \
# count  1232.000000    1232.000000         1232.000000    1232.000000
# mean      5.202922   50384.778409         2017.499188      18.074554
# std       0.627859   25986.624358            2.803618       3.337169
# min       4.000000    1000.000000         2007.000000      10.130000
# 25%       5.000000   30000.000000         2016.000000      16.000000
# 50%       5.000000   49341.000000         2018.000000      18.285000
# 75%       5.000000   69000.000000         2019.000000      20.380000
# max       8.000000  118146.000000         2023.000000      26.110000
#
#        engine(cc)  max_power(bhp)    torque(Nm)  price(in lakhs)
# count  1232.00000      1232.00000  1.232000e+03      1232.000000
# mean   1590.00974      1590.00974  1.479551e+04        91.820844
# std     538.93104       538.93104  9.100390e+04      2706.198523
# min     796.00000       796.00000  6.700000e+01         1.000000
# ...

# %%
show_boxplot(df, 'engine(cc)')

# %%
df = df[df['engine(cc)'] <= 3000]

# %%
df.shape
# Out:
# (1219, 12)

# %%
show_boxplot(df, 'engine(cc)')

# %%
df.describe()
# Out:
#              seats     kms_driven  manufacturing_year  mileage(kmpl)  \
# count  1219.000000    1219.000000         1219.000000    1219.000000
# mean      5.198523   50452.602953         2017.500410      18.117268
# std       0.622483   25845.164084            2.784951       3.305804
# min       4.000000    1000.000000         2007.000000      10.200000
# 25%       5.000000   30100.000000         2016.000000      16.045000
# 50%       5.000000   49341.000000         2018.000000      18.300000
# 75%       5.000000   69000.000000         2019.000000      20.425000
# max       8.000000  118146.000000         2023.000000      26.110000
#
#         engine(cc)  max_power(bhp)    torque(Nm)  price(in lakhs)
# count  1219.000000     1219.000000  1.219000e+03      1219.000000
# mean   1570.644791     1570.644791  1.488186e+04        92.396916
# std     507.689172      507.689172  9.147788e+04      2720.594443
# min     796.000000      796.000000  6.700000e+01         1.000000
# ...

# %%
show_boxplot(df, 'max_power(bhp)')

# %%
show_boxplot(df, 'torque(Nm)')

# %%
q25 = df['torque(Nm)'].quantile(0.25)
q75 = df['torque(Nm)'].quantile(0.75)
iqr = q75 - q25
lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr
df = df[(df['torque(Nm)'] > lower_bound) & (df['torque(Nm)'] < upper_bound)]

# %%
show_boxplot(df, 'torque(Nm)')

# %%
df = df[df['torque(Nm)'] < 20000]

# %%
show_boxplot(df, 'torque(Nm)')

# %%
show_boxplot(df, 'price(in lakhs)')

# %%
q25 = df['price(in lakhs)'].quantile(0.25)
q75 = df['price(in lakhs)'].quantile(0.75)
iqr = q75 - q25
lower_bound = q25 - 1.5 * iqr
upper_bound = q75 + 1.5 * iqr
df = df[(df['price(in lakhs)'] > lower_bound) & (df['price(in lakhs)'] < upper_bound)]

# %%
show_boxplot(df, 'price(in lakhs)')

# %%
df = df[df['price(in lakhs)'] < 17]

# %%
show_boxplot(df, 'price(in lakhs)')

# %%
df = df[df['price(in lakhs)'] < 14]

# %%
show_boxplot(df, 'price(in lakhs)')

# %%
df = df[df['price(in lakhs)'] < 13]

# %%
show_boxplot(df, 'price(in lakhs)')

# %%
show_boxplot(df, 'engine(cc)')

# %%
show_boxplot(df, 'max_power(bhp)')

# %%
df = df[df['max_power(bhp)'] < 1875]
df = df[df['engine(cc)'] < 1875]

# %%
show_boxplot(df, 'engine(cc)')

# %%
show_boxplot(df, 'torque(Nm)')

# %%
show_boxplot(df, 'seats')

# %%
show_boxplot(df, 'manufacturing_year')

# %%
show_boxplot(df, 'price(in lakhs)')

# %%
df = df[df['price(in lakhs)'] < 12]

# %%
250/2 + 1750
# Out:
# 1875.0

# %%
df.shape
# Out:
# (787, 12)

# %%
df.describe()
# Out:
#             seats     kms_driven  manufacturing_year  mileage(kmpl)  \
# count  787.000000     787.000000          787.000000     787.000000
# mean     5.069886   53801.855146         2017.021601      19.533837
# std      0.362274   25623.413943            2.718945       2.551422
# min      5.000000    1229.000000         2007.000000      11.880000
# 25%      5.000000   35040.000000         2015.000000      17.800000
# 50%      5.000000   52190.000000         2017.000000      19.010000
# 75%      5.000000   70233.000000         2019.000000      21.190000
# max      7.000000  118146.000000         2023.000000      26.110000
#
#         engine(cc)  max_power(bhp)    torque(Nm)  price(in lakhs)
# count   787.000000      787.000000    787.000000       787.000000
# mean   1285.794155     1285.794155   4420.491741         6.031283
# std     182.393866      182.393866   4238.876588         2.234521
# min     796.000000      796.000000     67.000000         1.000000
# ...

# %%
X = df.drop('price(in lakhs)', axis=1).values

# %%
y = df['price(in lakhs)'].values

# %%
X[0:5]
# Out:
# array([['Comprehensive', 'Petrol', 5.0, 30615, 'First Owner',
#         'Automatic', 2020.0, 17.4, 999.0, 999.0, 9863.0],
#        ['Third Party insurance', 'Petrol', 5.0, 42000, 'First Owner',
#         'Manual', 2017.0, 18.7, 1199.0, 1199.0, 887.0],
#        ['Comprehensive', 'Petrol', 5.0, 36739, 'First Owner', 'Manual',
#         2018.0, 18.9, 1197.0, 1197.0, 8186.0],
#        ['Comprehensive', 'Petrol', 5.0, 76000, 'First Owner', 'Manual',
#         2018.0, 15.8, 1591.0, 1591.0, 1213.0],
#        ['Comprehensive', 'Petrol', 5.0, 28783, 'First Owner', 'Manual',
#         2019.0, 17.0, 1198.0, 1198.0, 1085.0]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X[:, 5] = le.fit_transform(X[:, 5])
X
# Out:
# array([['Comprehensive', 'Petrol', 5.0, ..., 999.0, 999.0, 9863.0],
#        ['Third Party insurance', 'Petrol', 5.0, ..., 1199.0, 1199.0,
#         887.0],
#        ['Comprehensive', 'Petrol', 5.0, ..., 1197.0, 1197.0, 8186.0],
#        ...,
#        ['Comprehensive', 'Petrol', 5.0, ..., 1199.0, 1199.0, 887.0],
#        ['Comprehensive', 'Petrol', 5.0, ..., 999.0, 999.0, 75.0],
#        ['Comprehensive', 'Petrol', 5.0, ..., 1197.0, 1197.0, 8314.0]],
#       dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0, 1, 4])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
X
# Out:
# array([[1.0, 0.0, 0.0, ..., 999.0, 999.0, 9863.0],
#        [0.0, 0.0, 1.0, ..., 1199.0, 1199.0, 887.0],
#        [1.0, 0.0, 0.0, ..., 1197.0, 1197.0, 8186.0],
#        ...,
#        [1.0, 0.0, 0.0, ..., 1199.0, 1199.0, 887.0],
#        [1.0, 0.0, 0.0, ..., 999.0, 999.0, 75.0],
#        [1.0, 0.0, 0.0, ..., 1197.0, 1197.0, 8314.0]], dtype=object)

# %%
df.insurance_validity.unique()
# Out:
# array(['Comprehensive', 'Third Party insurance', 'Third Party',
#        'Zero Dep'], dtype=object)

# %%
df.ownsership.unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner'], dtype=object)

# %%
df.transmission.unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
df.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df.shape
# Out:
# (787, 12)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.02594810e-01, 2.02594810e-01, 5.54103739e-01],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, ...,
#         4.02195609e-01, 4.02195609e-01, 4.63827140e-02],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         4.00199601e-01, 4.00199601e-01, 4.59245432e-01],
#        ...,
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         4.02195609e-01, 4.02195609e-01, 4.63827140e-02],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.02594810e-01, 2.02594810e-01, 4.52514282e-04],
#        [1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         4.00199601e-01, 4.00199601e-01, 4.66485661e-01]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
len(y)
# Out:
# 787

# %%
len(X)
# Out:
# 787

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge, LinearRegression, Lasso
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# Standardizing the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Initializing the models
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(random_state=42, alpha=0.5),
    "Lasso Regression": Lasso(random_state=42),
    "Random Forest Regressor": RandomForestRegressor(n_estimators=10, random_state=42),
    "Decision Tree Regressor": DecisionTreeRegressor(random_state=42),
    "Support Vector Regressor": SVR(),
    "Polynomial Regression": Pipeline([
        ("poly_features", PolynomialFeatures(degree=1)),
        ("linear_regression", LinearRegression())
    ])
}

# Dictionary to store the R^2 scores and MSE for each model
performance_metrics = {}

# Fitting each model and evaluating the performance
for name, model in models.items():
    model.fit(X_train, y_train)  # Fit model
    y_pred = model.predict(X_test)  # Make predictions
    r2 = r2_score(y_test, y_pred)  # Calculate R^2 score
    mse = mean_squared_error(y_test, y_pred)  # Calculate Mean Squared Error
    performance_metrics[name] = (r2, mse)
    print(f'{name} - R^2 Score: {r2:.2f}, MSE: {mse:.2f}')
# Out:
# Linear Regression - R^2 Score: 0.70, MSE: 1.50
# Ridge Regression - R^2 Score: 0.71, MSE: 1.48
# Lasso Regression - R^2 Score: 0.22, MSE: 3.96
# Random Forest Regressor - R^2 Score: 0.90, MSE: 0.52
# Decision Tree Regressor - R^2 Score: 0.71, MSE: 1.49
# Support Vector Regressor - R^2 Score: 0.68, MSE: 1.60
# Polynomial Regression - R^2 Score: 0.71, MSE: 1.49
